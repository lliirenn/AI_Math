# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([0.2,0.7,-1,3])

# %%
plt.plot([1,2,2.5,4],[1,2,3,4])

# %%
X = [1,2,2.5,4]
Y = [1,2,3,4]

# %%
plt.plot(X,Y)

# %%
plt.scatter(X,Y)

# %%
plt.plot(np.random.randn(100))

# %%
x = np.linspace(0,10,1000)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)
